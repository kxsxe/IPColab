# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/abcdef.bmp')
print(img.shape)
gImg1 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
print(gImg1.shape)
plt.imshow(gImg1, cmap ='gray')
# Out:
# (256, 256, 3)
# (256, 256)

# %%
def saturation(val):
  if val > 255:
    return 255
  elif val < 0:
    return 0
  else:
    return val

# %%
gPoint = np.zeros((gImg1.shape[0], gImg1.shape[1]), dtype=np.ubyte)

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/a.bmp')
print(img.shape)
gImg2 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gImg2, cmap ='gray')
# Out:
# (256, 256, 3)

# %%
for h in range(gImg1.shape[0]):
  for w in range(gImg1.shape[1]):
    #pointVal = np.int32(gImg1[h,w]) & np.int32(gImg2[h,w])
    pointVal = np.int32(gImg1[h,w]) | np.int32(gImg2[h,w])
    gPoint[h,w] = saturation(pointVal)

plt.imshow(gPoint, cmap='gray')

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/lena256.jpg')
print(img.shape)
gImg2 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gImg2, cmap ='gray')
# Out:
# (256, 256, 3)

# %%
planeNum = 8
planeValue = 1

for i in range(planeNum-1):
  planeValue *= 2

for h in range(gImg2.shape[0]):
  for w in range(gImg2.shape[1]):
    imValue = gImg2[h,w]
    imValue = (int)(imValue/planeValue);
    if(imValue % 2 == 0):
      imValue = 0
    else:
      imValue = 255
    gPoint[h,w] = imValue & planeValue

  plt.imshow(gPoint, cmap='gray')

# %%
gWaterMarker = gImg2.copy()

# %%
for h in range(gImg2.shape[0]):
  for w in range(gImg2.shape[1]):
    imValue = gImg1[h,w]
    if(imValue >= 128):
      if(gWaterMarker[h,w] % 2 == 0):
        gWaterMarker[h,w] += 1
    else:
      if(gWaterMarker[h,w] % 2 == 1):
        gWaterMarker[h,w] -= 1

    plt.imshow(gWaterMarker, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1421595158.py in <cell line: 0>()
#       9         gWaterMarker[h,w] -= 1
#      10
# ---> 11     plt.imshow(gWaterMarker, cmap='gray')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3590     **kwargs,
#    3591 ) -> AxesImage:
# -> 3592     __ret = gca().imshow(
#    3593         X,
#    3594         cmap=cmap,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5954         # update ax.dataLim, and, if autoscaling, set viewLim
#    5955         # to tightly fit the image, regardless of dataLim.
# -> 5956         im.set_extent(im.get_extent())
#    5957
#    5958         self.add_image(im)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/image.py in set_extent(self, extent, **kwargs)
#     950         self.sticky_edges.y[:] = [ymin, ymax]
#     951         if self.axes.get_autoscalex_on():
# --> 952             self.axes.set_xlim((xmin, xmax), auto=None)
#     953         if self.axes.get_autoscaley_on():
#     954             self.axes.set_ylim((ymin, ymax), auto=None)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3781                 raise TypeError("Cannot pass both 'right' and 'xmax'")
#    3782             right = xmax
# -> 3783         return self.xaxis._set_lim(left, right, emit=emit, auto=auto)
#    3784
#    3785     get_xscale = _axis_method_wrapper("xaxis", "get_scale")
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in _set_lim(self, v0, v1, emit, auto)
#    1258         v0, v1 = sorted([v0, v1], reverse=bool(reverse))
#    1259
# -> 1260         self.set_view_interval(v0, v1, ignore=True)
#    1261         # Mark viewlims as no longer stale without triggering an autoscale.
#    1262         for ax in self._get_shared_axes():
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in setter(self, vmin, vmax, ignore)
#    2361         # docstring inherited.
#    2362         if ignore:
# -> 2363             setattr(getattr(self.axes, lim_name), attr_name, (vmin, vmax))
#    2364         else:
#    2365             oldmin, oldmax = getter(self)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in viewLim(self)
#     866     def viewLim(self):
#     867         """The view limits as `.Bbox` in data coordinates."""
# --> 868         self._unstale_viewLim()
#     869         return self._viewLim
#     870
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _unstale_viewLim(self)
#     854         need_scale = {
#     855             name: any(ax._stale_viewlims[name]
# --> 856                       for ax in self._shared_axes[name].get_siblings(self))
#     857             for name in self._axis_names}
#     858         if any(need_scale.values()):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in get_siblings(self, a)
#     872         """Return all of the items joined with *a*, including itself."""
#     873         siblings = self._mapping.get(a, [a])
# --> 874         return sorted(siblings, key=self._ordering.get)
#     875
#     876
#
# /usr/lib/python3.12/weakref.py in get(self, key, default)
#     450
#     451     def get(self, key, default=None):
# --> 452         return self.data.get(ref(key),default)
#     453
#     454     def __contains__(self, key):
#
# KeyboardInterrupt:
